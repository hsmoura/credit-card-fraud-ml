# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocess import load_and_preprocess

X_train_res, X_test, y_train_res, y_test = load_and_preprocess("../data/creditcard.csv")

rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(max_depth=10, n_jobs=-1, random_state=42)

# %%
xgb = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    scale_pos_weight=1,  # we used SMOTE already
    random_state=42,
    n_jobs=-1
)

xgb.fit(X_train_res, y_train_res)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
from sklearn.metrics import classification_report, roc_auc_score

def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    
    print(classification_report(y_test, y_pred))
    print("ROC-AUC:", roc_auc_score(y_test, y_proba))

# %%
evaluate_model(rf, X_test, y_test)
evaluate_model(xgb, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.52      0.89      0.66        98
#
#     accuracy                           1.00     56962
#    macro avg       0.76      0.94      0.83     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC: 0.9816201276515109
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.74      0.86      0.79        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.93      0.90     56962
# weighted avg       1.00      1.00      1.00     56962
#
# ROC-AUC: 0.9834964268487361

# %%
import numpy as np

y_scores = xgb.predict_proba(X_test)[:, 1]

threshold = 0.3  # try different values
y_pred_custom = (y_scores >= threshold).astype(int)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_custom))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.67      0.87      0.76        98
#
#     accuracy                           1.00     56962
#    macro avg       0.84      0.93      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(y_test, y_scores)

plt.plot(fpr, tpr)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.show()

# %%
import pandas as pd

feature_importance = pd.Series(
    rf.feature_importances_,
    index=X_train_res.columns
).sort_values(ascending=False)

feature_importance.head(10)
# Out:
# V14    0.221006
# V10    0.129925
# V4     0.118860
# V12    0.109548
# V17    0.086288
# V3     0.075463
# V11    0.052105
# V16    0.040578
# V2     0.037409
# V9     0.025589
# dtype: float64

# %%
pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (0.51.0)
# Requirement already satisfied: numpy>=2 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (2.4.3)
# Requirement already satisfied: scipy in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (1.17.1)
# Requirement already satisfied: scikit-learn in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (1.8.0)
# Requirement already satisfied: pandas in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (3.0.1)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (4.67.3)
# Requirement already satisfied: packaging>20.9 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (0.64.0)
# Requirement already satisfied: llvmlite in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (0.46.0)
# Requirement already satisfied: cloudpickle in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from shap) (4.15.0)
# Requirement already satisfied: colorama in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (from scikit-learn->shap) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import shap


explainer = shap.Explainer(xgb)
shap_values = explainer(X_test[:1000])

shap.plots.bar(shap_values)

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\hs-mo\desktop\credit-card-fraud-ml\venv\lib\site-packages (1.5.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib

joblib.dump(xgb, "../models/xgb_model.pkl")
# Out:
# ['../models/xgb_model.pkl']
